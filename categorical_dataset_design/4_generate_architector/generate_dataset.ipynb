# %% [markdown]
# ## Define Chemical Space

# %%
import os
import json
from collections import defaultdict
import copy

import pickle
import pandas as pd
import rdkit
rdkit.__version__

from architector import build_complex
from nglview import show_rdkit

def view3D(mol):
    """Display an RDKit molecule in 3D using nglview"""
    return show_rdkit(mol)

ligands = {}
with open("../../ligand_dictionaries/ligands.json", "r") as f:
    ligands.update(json.load(f))

for lig_name, tmp in ligands.items():
    print(lig_name, tmp["smiles"])
    
LIGAND_DICT = dict(sorted(ligands.items()))

# Checkpoint file to save progress
os.makedirs("chk", exist_ok=True)
CHECKPOINT_FILE = "chk/dataset_checkpoint.pkl"
PROGRESS_LOG = "chk/dataset_progress.txt"

def save_checkpoint(data_dict, progress_state):
    """Save current dataframe and progress state"""
    with open(CHECKPOINT_FILE, 'wb') as f:
        pickle.dump({'data': data_dict, 'state': progress_state}, f)
    print(f"✓ Checkpoint saved: {len(data_dict['metals'])} complexes", flush=True)

def load_checkpoint():
    """Load previous checkpoint if it exists"""
    try:
        with open(CHECKPOINT_FILE, 'rb') as f:
            checkpoint = pickle.load(f)
            print(f"✓ Loaded checkpoint: {len(checkpoint['data']['metals'])} complexes")
            return checkpoint['data'], checkpoint['state']
    except FileNotFoundError:
        print("No checkpoint found, starting fresh")
        return None, None

def make_state_key(metal, ox_state, cn, ligand_labels, coreType):
    """Create unique key for current state"""
    return f"{metal}_{ox_state}_{cn}_{coreType}_{'_'.join(sorted(ligand_labels))}"

def ligand_dicts_from_labels(ligand_labels):
    """Process ligand labels into dicts that are usable by Architector""" 
    ligand_dicts = []
    for lig_type, lig_subtype in [x.split("|") for x in ligand_labels]:
        ligand_dicts.append(copy.deepcopy(LIGAND_DICT[lig_type]))
        if 'functional_inds' in ligand_dicts[-1]:
            if lig_subtype != "D": # if not electron donating
                if lig_type == "halide":
                    ligand_dicts[-1]['smiles'] = '[F-]' if lig_subtype == "W" else "[Cl-]"
                else:
                    ligand_dicts[-1]['smiles'].replace(
                        "[H]",
                        '[F]' if lig_subtype == "W" else '[C]([H])([H])[H]'
                    )
            del ligand_dicts[-1]['functional_inds']
    return ligand_dicts
# Out:
# hydride [H-1]
# halide [Br-]
# methyl [C-]([H])([H])[H]
# methanediide [C-2]([H])[H]
# ammonia [N]([H])([H])[H]
# amine [N-]([H])[H]
# imido [N-2][H]
# water [O]([H])[H]
# hydroxyl [O-][H]
# oxo [O-2]
# phosphine [P]([H])([H])[H]
# phosphido [P-]([H])[H]
# hydrogen sulfide [S]([H])[H]
# thiol [S-][H]
# sulfido [S-2]

# %%
# Initialize progress log file
if not os.path.exists(PROGRESS_LOG):
    with open(PROGRESS_LOG, 'w') as f:
        f.write("Progress log initialized\n")
    print("Progress log initialized")

# %%
LIGAND_DICT
# Out:
# {'amine': {'smiles': '[N-]([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -1,
#   'functional_inds': [0, 0]},
#  'ammonia': {'smiles': '[N]([H])([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'L',
#   'charge': 0,
#   'functional_inds': [0, 0, 0]},
#  'halide': {'smiles': '[Br-]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -1},
#  'hydride': {'smiles': '[H-1]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -1},
#  'hydrogen sulfide': {'smiles': '[S]([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'L',
#   'charge': 0,
#   'functional_inds': [0, 0]},
#  'hydroxyl': {'smiles': '[O-][H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -1,
#   'functional_inds': [0]},
#  'imido': {'smiles': '[N-2][H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -2,
#   'functional_inds': [0]},
#  'methanediide': {'smiles': '[C-2]([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -2,
#   'functional_inds': [0, 0]},
#  'methyl': {'smiles': '[C-]([H])([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -1,
#   'functional_inds': [0, 0, 0]},
#  'oxo': {'smiles': '[O-2]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -2},
#  'phosphido': {'smiles': '[P-]([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -1,
#   'functional_inds': [0, 0]},
#  'phosphine': {'smiles': '[P]([H])([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'L',
#   'charge': 0,
#   'functional_inds': [0, 0, 0]},
#  'sulfido': {'smiles': '[S-2]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': 0},
#  'thiol': {'smiles': '[S-][H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'X',
#   'charge': -1,
#   'functional_inds': [0]},
#  'water': {'smiles': '[O]([H])[H]',
#   'coordList': [0],
#   'ligType': 'mono',
#   'bondType': 'L',
#   'charge': 0,
#   'functional_inds': [0, 0]}}

# %% [markdown]
# ## Create Dataset

# %%
df = pd.read_csv("../2_generate_subset_metadata/a_subset1/selected_design.csv", converters={'Ligand_multiset_variants': eval})
df.columns
# Out:
# Index(['Element', 'Ox', 'CN', 'Geometry', 'Charge', 'Ligand_multiset_variants',
#        'MW', 'count_type_halide', 'count_type_methyl',
#        'count_type_methanediide', 'count_type_ammonia', 'count_type_amine',
#        'count_type_imido', 'count_type_water', 'count_type_hydroxyl',
#        'count_type_oxo', 'count_type_phosphine', 'count_type_phosphido',
#        'count_type_hydrogen sulfide', 'count_type_thiol', 'count_type_sulfido',
#        'count_prop_N', 'count_var_halide_N', 'count_var_methyl_N',
#        'count_var_methanediide_N', 'count_var_ammonia_N', 'count_var_amine_N',
#        'count_var_imido_N', 'count_var_water_N', 'count_var_hydroxyl_N',
#        'count_var_oxo_N', 'count_var_phosphine_N', 'count_var_phosphido_N',
#        'count_var_hydrogen sulfide_N', 'count_var_thiol_N',
#        'count_var_sulfido_N'],
#       dtype='object')

# %% [markdown]
# ### Strategy for Handling Kernel Crashes
#
# Since the kernel can crash during `build_complex` (likely due to underlying C/Fortran code in xtb), we need to:
# 1. Save progress incrementally to disk
# 2. Restart from the last saved checkpoint if the kernel crashes

# %%
errors = defaultdict(list)
status = []
# Load checkpoint if exists
checkpoint_data, last_state = load_checkpoint()
if checkpoint_data:
    df_metals = checkpoint_data['metals']
    df_cn = checkpoint_data['cn']
    df_ligands = checkpoint_data['ligands']
    df_ox = checkpoint_data['ox']
    df_chg = checkpoint_data['chg']
    df_multiplicity = checkpoint_data['multiplicity']
    df_mol2 = checkpoint_data['mol2']
    df_geo = checkpoint_data['geo']
    df_energy = checkpoint_data['energy']
    errors = checkpoint_data.get('errors', defaultdict(list))
    print(f"Resuming from checkpoint with {len(df_metals)} existing complexes")
else:
    # Start fresh
    df_metals, df_cn, df_ligands, df_ox, df_chg, df_multiplicity, df_mol2, df_geo, df_energy = [], [], [], [], [], [], [], [], []
    last_state = None
# Out:
# ✓ Loaded checkpoint: 110 complexes
# Resuming from checkpoint with 110 existing complexes

# %%
# Track processed states to avoid duplicates
if os.path.exists(PROGRESS_LOG):
    with open(PROGRESS_LOG, "r") as f:
        # Read from the end and stop at the most recent STARTING line
        for line in reversed(f.readlines()):
            if line.startswith("STARTING: "):
                last_state = line.split("STARTING: ", 1)[1].strip()
                flag_repeat = True
                break
            else:
                flag_repeat = False
    print(f"Progress file found, last state {last_state}")
else:
    print("No progress file found")
    flag_repeat = False
# Out:
# Progress file found, last state Fe_0_1_single_thiol|N

# %%
print(len(df))
# Out:
# 48089

# %%
# Track processed states to avoid duplicates
if os.path.exists(PROGRESS_LOG):
    with open(PROGRESS_LOG, "r") as f:
        # Read from the end and stop at the most recent STARTING line
        for line in reversed(f.readlines()):
            if line.startswith("STARTING: "):
                last_state = line.split("STARTING: ", 1)[1].strip()
                flag_repeat = True
                break
            else:
                flag_repeat = False
else:
    flag_repeat = False

checkpoint_counter = 0
CHECKPOINT_EVERY = 5  # Save every N successful complexes

n_errors = sum(len(v) for v in errors.values())
print(f"Analyzing {len(df)-len(df_metals)-n_errors} of {len(df)} structures ({len(df_metals)+n_errors} have been assessed)")

for i, row in df.iterrows():
    row = row.to_dict()
    metal = row["Element"]
    ox_state = row["Ox"]
    cn = row["CN"]
    coreType = row["Geometry"]
    ligand_labels = row["Ligand_multiset_variants"]
    state_key = make_state_key(metal, ox_state, cn, ligand_labels, coreType)
                    
    # Skip if already processed
    if flag_repeat:
        if state_key == last_state:
            flag_repeat = False
        else:
            continue
#    print(i, state_key, last_state)

    # Log to file in case kernel dies
    with open(PROGRESS_LOG, 'a') as f:
        f.write(f"STARTING: {state_key}\n")
    
    print(f"\nProcessing: {metal=}, {ox_state=}, {cn=}, {coreType=}, ligands={ligand_labels}", flush=True)

    ligand_dicts = ligand_dicts_from_labels(ligand_labels)
    inputDict = {
        "core": {"metal": metal, 'coreCN': cn, "coreType": [coreType]},
        "ligands": ligand_dicts,
        'parameters':{
            "debug": False,
            "metal_ox": ox_state,
            "full_method": "GFN2-xTB",
            'assemble_method':'GFN2-xTB', # Switch to GFN-FF for faster assembly, 
            'n_symmetries': 100, # build 5 structures with different ligand arrangements, duplicates will be filtered
            'n_conformers': 1,
            'return_only_1':True, # Return just one geometry with lowest energy
            'save_init_geos': True,
        },
    }

    try:
        print("  Calling build_complex...", flush=True)
        out = build_complex(inputDict)
        if len(out) > 0:
            print(f"  build_complex completed, {len(out)} options available, taking the first", flush=True)
            out = next(iter(out.values()))
        else:
            raise ValueError("No build_complex output was produced.")
        
        n_el = [out['xtb_n_unpaired_electrons'], out['calc_n_unpaired_electrons']]
        if len(set(n_el)) > 1:
            raise ValueError(f"N_unpaired_el should agree between keys: 'xtb_n_unpaired_electrons', 'calc_n_unpaired_electrons', 'metal_spin', resulting {n_el}")
        chg = [out['total_charge'], out['xtb_total_charge']]
        if len(set(chg)) > 1:
            raise ValueError(f"Charge should agree between keys: 'total_charge', 'xtb_total_charge', resulting {chg}")
        if ox_state != out["metal_ox"]:
            raise ValueError("Metal oxidation state is not equal to assigned.")
        status.append("complete")
    except Exception as e:
        error_msg = f"{type(e).__name__}: {str(e)[:100]}"
        print(f"  ERROR: {error_msg}", flush=True)
        errors[str(e)[:30]].append([metal, ox_state, cn, ligand_labels, coreType, e])
        with open(PROGRESS_LOG, 'a') as f:
            f.write(f"ERROR: {state_key} - {error_msg}\n")
        status.append("error")
    else:
        print("  SUCCESS", flush=True)
        df_metals.append(metal)
        df_ox.append(ox_state)
        df_cn.append(cn)
        df_geo.append(coreType)
        df_ligands.append(ligand_labels)
        df_chg.append(out['total_charge'])
        df_multiplicity.append(out['xtb_n_unpaired_electrons'] + 1)
        df_mol2.append(out['mol2string'])
        df_energy.append(out['energy'])
        
        checkpoint_counter += 1
    
    # Save checkpoint periodically
    if checkpoint_counter >= CHECKPOINT_EVERY:
        data_dict = {
            'metals': df_metals, 'cn': df_cn, 'ligands': df_ligands,
            'ox': df_ox, 'chg': df_chg, 'multiplicity': df_multiplicity,
            'mol2': df_mol2, 'geo': df_geo, 'energy': df_energy,
            'errors': errors
        }
        save_checkpoint(data_dict, state_key)
        checkpoint_counter = 0
                    
        with open(PROGRESS_LOG, 'a') as f:
            f.write(f"SUCCESS: {state_key}\n")


# Final checkpoint
data_dict = {
    'metals': df_metals, 'cn': df_cn, 'ligands': df_ligands,
    'ox': df_ox, 'chg': df_chg, 'multiplicity': df_multiplicity,
    'mol2': df_mol2, 'geo': df_geo, 'energy': df_energy,
    'errors': errors
}
#save_checkpoint(data_dict, "COMPLETED")

df_final = pd.DataFrame({
    "metal": df_metals,
    "oxidation_state": df_ox,
    "coordination_number": df_cn,
    "geometry": df_geo,
    "ligand_names": df_ligands,
    "total_charge": df_chg,
    "multiplicity": df_multiplicity,
    "mol2string": df_mol2,
    "xtb_energy": df_energy,
}) # Create a dataframe

print(f"\nGenerated {len(df_final)} complexes with {len(errors)} error types.")
# Out:
# Analyzing 47514 of 48089 structures (575 have been assessed)
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['methyl|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['methyl|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'ammonia|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'amine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'hydroxyl|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'phosphido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['ammonia|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['water|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['water|N', 'hydroxyl|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['water|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['water|N', 'phosphido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['water|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['water|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['water|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['hydroxyl|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['hydroxyl|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['hydroxyl|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphine|N', 'phosphine|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphine|N', 'phosphido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphine|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
# ✓ Checkpoint saved: 119 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphine|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphine|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphido|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphido|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['hydrogen sulfide|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['hydrogen sulfide|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['hydrogen sulfide|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['thiol|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['sulfido|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'halide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'methyl|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'ammonia|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'amine|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
# ✓ Checkpoint saved: 124 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'hydroxyl|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'phosphine|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'phosphido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['halide|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['methyl|N', 'ammonia|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['methyl|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['methyl|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['methyl|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['methyl|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
# ✓ Checkpoint saved: 129 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'ammonia|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'amine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'hydroxyl|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'phosphine|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'phosphido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['ammonia|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
# ✓ Checkpoint saved: 134 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['water|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['water|N', 'hydroxyl|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['water|N', 'phosphine|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['water|N', 'phosphido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['water|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['water|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['water|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['hydroxyl|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['hydroxyl|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['hydroxyl|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphine|N', 'phosphine|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
# ✓ Checkpoint saved: 139 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphine|N', 'phosphido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphine|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphine|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphine|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphido|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphido|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['hydrogen sulfide|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['hydrogen sulfide|N', 'thiol|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['hydrogen sulfide|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['thiol|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['sulfido|N', 'sulfido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
# ✓ Checkpoint saved: 144 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine|N', 'hydrogen sulfide|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['halide|N', 'halide|N', 'halide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['ammonia|N', 'ammonia|N', 'ammonia|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['water|N', 'water|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['phosphine|N', 'phosphine|N', 'phosphine|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['halide|N', 'methyl|N', 'ammonia|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['water|N', 'hydroxyl|N', 'phosphine|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['hydrogen sulfide|N', 'hydrogen sulfide|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['sulfido|N', 'sulfido|N', 'sulfido|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['halide|N', 'amine|N', 'water|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['halide|N', 'hydroxyl|N', 'hydrogen sulfide|N']
#   Calling build_complex...
#   ERROR: ValueError: No build_complex output was produced.
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['halide|N', 'phosphine|N', 'phosphido|N']
#   Calling build_complex...
#   build_complex completed, 1 options available, taking the first
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['halide|N', 'thiol|N', 'sulfido|N']
#   Calling build_complex...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 62
#      60 try:
#      61     print("  Calling build_complex...", flush=True)
# ---> 62     out = build_complex(inputDict)
#      63     if len(out) > 0:
#      64         print(f"  build_complex completed, {len(out)} options available, taking the first", flush=True)
#
# File ~/bin/Architector/architector/complex_construction.py:684, in build_complex(inputDict)
#     667 def build_complex(inputDict):
#     668     """build_complex build a complex!
#     669     main function for architector!!!!
#     670     Attempts a default radii, larger radii, and smaller radii build_complex_driver
#    (...)    682         ordered structures and outputs as valid
#     683     """
# --> 684     ordered_conf_dict = build_complex_driver(inputDict)
#     685     # Try larger radii generation for multidentate complexes if no complexes generated in an attempt to get at high-spin
#     686     # > Covalent radii typically understimated for higher spin conformations
#     687     in_metal = inputDict['parameters']['original_metal']
#
# File ~/bin/Architector/architector/complex_construction.py:570, in build_complex_driver(inputDict1, in_metal)
#     555 def build_complex_driver(inputDict1,in_metal=False):
#     556     """build_complex_driver overall driver building of the complex
#     557
#     558     Parameters
#    (...)    568         Conformer dictionary with stored values if generation successful.
#     569     """
# --> 570     conf_dict,inputDict,core_preprocess_time,symmetry_preprocess_time,int_time1 = complex_driver(
#     571         inputDict1=inputDict1,
#     572         in_metal=in_metal
#     573     )
#     575     if len(conf_dict) == 0:
#     576         if inputDict['parameters']['debug']:
#
# File ~/bin/Architector/architector/complex_construction.py:502, in complex_driver(inputDict1, in_metal)
#     500             break
#     501 else: # Use the first conformer ligand structures to map to other symmetries
# --> 502     tcomplexClass, _ = gen_aligned_complex(
#     503             newLigInputDicts,
#     504             ligandDict,
#     505             inputDict,
#     506             ligLists,
#     507             coreCoordList,
#     508             coreType)
#     509     if (tcomplexClass is not None):
#     510         complexClass = tcomplexClass
#
# File ~/bin/Architector/architector/complex_construction.py:402, in gen_aligned_complex(newLigInputDicts, ligandDict, inputDict, ligLists, coreCoordList, coreType)
#     400 coreCoordList = coreCoordList
#     401 complexClass = Complex(coreSmiles, coreCoordList, ligandList, inputDict['parameters'])
# --> 402 complexClass.final_eval(single_point=True) # Key here - have singlepoints during assembly be defined by assembly params.
#     403 if inputDict['parameters']['debug']:
#     404     print('Complex class generated: ', complexClass.calculator.successful)
#
# File ~/bin/Architector/architector/complex_construction.py:270, in Complex.final_eval(self, single_point)
#     268     if (not self.calculator.successful):
#     269         tmp_relax = CalcExecutor(self.complexMol,method='UFF',fix_m_neighbors=False,relax=single_point)
# --> 270         self.calculator = CalcExecutor(tmp_relax.mol,parameters=self.parameters,
#     271                                         final_sanity_check=self.parameters['full_sanity_checks'],
#     272                                         relax=single_point)
#     273 else: # Ensure calculation object at least exists
#     274     self.calculator = CalcExecutor(self.complexMol,method='UFF',fix_m_neighbors=False,relax=False)
#
# File ~/bin/Architector/architector/io_calc.py:193, in CalcExecutor.__init__(self, structure, parameters, init_sanity_check, final_sanity_check, relax, assembly, method, xtb_solvent, xtb_accuracy, xtb_electronic_temperature, xtb_max_iterations, fmax, maxsteps, ff_preopt_run, detect_spin_charge, fix_m_neighbors, default_params, ase_opt_method, species_run, calculator)
#     191 self.calc_time = time.time()
#     192 self.done = False
# --> 193 self.calculate()
#
# File ~/bin/Architector/architector/io_calc.py:255, in CalcExecutor.calculate(self)
#     253     else:
#     254         dyn = self.opt_method(self.mol.ase_atoms)
# --> 255 dyn.run(fmax=self.fmax,steps=self.maxsteps)
#     256 if self.parameters['save_trajectories']:
#     257     self.read_traj()
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/optimize/optimize.py:417, in Optimizer.run(self, fmax, steps)
#     402 """Run optimizer.
#     403
#     404 Parameters
#    (...)    414     True if the forces on atoms are converged.
#     415 """
#     416 self.fmax = fmax
# --> 417 return Dynamics.run(self, steps=steps)
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/optimize/optimize.py:286, in Dynamics.run(self, steps)
#     268 def run(self, steps=DEFAULT_MAX_STEPS):
#     269     """Run dynamics algorithm.
#     270
#     271     This method will return when the forces on all individual
#    (...)    283         True if the forces on atoms are converged.
#     284     """
# --> 286     for converged in Dynamics.irun(self, steps=steps):
#     287         pass
#     288     return converged
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/optimize/optimize.py:257, in Dynamics.irun(self, steps)
#     254 # run the algorithm until converged or max_steps reached
#     255 while not is_converged and self.nsteps < self.max_steps:
#     256     # compute the next step
# --> 257     self.step()
#     258     self.nsteps += 1
#     260     # log the step
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/optimize/lbfgs.py:158, in LBFGS.step(self, forces)
#     156 if self.use_line_search is True:
#     157     e = self.func(pos)
# --> 158     self.line_search(pos, g, e)
#     159     dr = (self.alpha_k * self.p).reshape(len(self.optimizable), -1)
#     160 else:
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/optimize/lbfgs.py:247, in LBFGS.line_search(self, r, g, e)
#     244 r = r.ravel()
#     245 ls = LineSearch()
#     246 self.alpha_k, e, self.e0, self.no_update = \
# --> 247     ls._line_search(self.func, self.fprime, r, self.p, g, e, self.e0,
#     248                     maxstep=self.maxstep, c1=.23,
#     249                     c2=.46, stpmax=50.)
#     250 if self.alpha_k is None:
#     251     raise RuntimeError('LineSearch failed!')
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/utils/linesearch.py:61, in LineSearch._line_search(self, func, myfprime, xk, pk, gfk, old_fval, old_old_fval, maxstep, c1, c2, xtrapl, xtrapu, stpmax, stpmin, args)
#      59 if self.task[:2] == 'FG':
#      60     alpha1 = stp
# ---> 61     fval = func(xk + stp * pk, *args)
#      62     self.fc += 1
#      63     gval = fprime(xk + stp * pk, *newargs)
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/optimize/lbfgs.py:229, in LBFGS.func(self, x)
#     227 self.optimizable.set_positions(x.reshape(-1, 3))
#     228 self.function_calls += 1
# --> 229 return self.optimizable.get_potential_energy()
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/optimize/optimize.py:59, in OptimizableAtoms.get_potential_energy(self)
#      57 def get_potential_energy(self):
#      58     force_consistent = self._use_force_consistent_energy
# ---> 59     return self.atoms.get_potential_energy(
#      60         force_consistent=force_consistent)
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/atoms.py:772, in Atoms.get_potential_energy(self, force_consistent, apply_constraint)
#     769     energy = self._calc.get_potential_energy(
#     770         self, force_consistent=force_consistent)
#     771 else:
# --> 772     energy = self._calc.get_potential_energy(self)
#     773 if apply_constraint:
#     774     for constraint in self.constraints:
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/calculators/abc.py:26, in GetPropertiesMixin.get_potential_energy(self, atoms, force_consistent)
#      24 else:
#      25     name = 'energy'
# ---> 26 return self.get_property(name, atoms)
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/ase/calculators/calculator.py:515, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     512     if self.use_cache:
#     513         self.atoms = atoms.copy()
# --> 515     self.calculate(atoms, [name], system_changes)
#     517 if name not in self.results:
#     518     # For some reason the calculator was not able to do what we want,
#     519     # and that is OK.
#     520     raise PropertyNotImplementedError(
#     521         '{} not present in this ' 'calculation'.format(name)
#     522     )
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/xtb/ase/calculator.py:231, in XTB.calculate(self, atoms, properties, system_changes)
#     228     self._xtb = self._create_api_calculator()
#     230 try:
# --> 231     self._res = self._xtb.singlepoint(self._res)
#     232 except XTBException:
#     233     raise ase_calc.CalculationFailed("xtb could not evaluate input")
#
# File ~/mamba/envs/architector/lib/python3.11/site-packages/xtb/interface.py:821, in Calculator.singlepoint(self, res, copy)
#     818 else:
#     819     _res = Results(self)
# --> 821 _lib.xtb_singlepoint(
#     822     self._env, self._mol, self._calc, _res._res,
#     823 )
#     825 if self.check() != 0:
#     826     raise XTBException(self.get_error("Single point calculation failed"))
#
# KeyboardInterrupt:

# %%
out
# Out:
# {}

# %%
len(df_final)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 len(df_final)
#
# NameError: name 'df_final' is not defined

# %%
errors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 errors
#
# NameError: name 'errors' is not defined

# %%
len(df_final)
# Out:
# 310

# %%
df_final.head()
# Out:
#   metal  oxidation_state  coordination_number  geometry      ligand_names  \
# 0    Fe                2                    2  bent_109    [amine, amine]
# 1    Fe                2                    2  bent_120    [amine, amine]
# 2    Fe                2                    2    linear    [amine, amine]
# 3    Fe                2                    2  bent_109  [amine, bromide]
# 4    Fe                2                    2  bent_120  [amine, bromide]
#
#    total_charge  multiplicity  \
# 0             2             5
# 1             2             5
# 2             2             5
# 3             2             5
# 4             2             5
#
#                                           mol2string  xtb_energy
# 0  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -298.173926
# 1  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -298.174912
# 2  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -298.173683
# 3  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -301.972133
# 4  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -301.971854

# %%
# Analyze each column independently for unique values and their counts
columns_to_analyze = ['metal', 'oxidation_state', 'coordination_number', 'geometry', 'ligand_names', 'total_charge', 'multiplicity']

for col in columns_to_analyze:
    print(f"\nColumn: {col}")
    print(f"{'='*60}")
    value_counts = df[col].value_counts().sort_index()
    print(value_counts)
    print(f"Total unique values: {len(value_counts)}")
# Out:
# Column: metal
# ============================================================
# metal
# Fe    310
# Name: count, dtype: int64
# Total unique values: 1
#
# Column: oxidation_state
# ============================================================
# oxidation_state
# 0      1
# 2    309
# Name: count, dtype: int64
# Total unique values: 2
#
# Column: coordination_number
# ============================================================
# coordination_number
# 2    310
# Name: count, dtype: int64
# Total unique values: 1
#
# Column: geometry
# ============================================================
# geometry
# bent_109    104
# bent_120    103
# linear      103
# Name: count, dtype: int64
# Total unique values: 3
#
# Column: ligand_names
# ============================================================
# ligand_names
# [amine, amine]                              4
# [amine, bromide]                            3
# [amine, choride]                            3
# [amine, dimethylamine]                      3
# [amine, fluoride]                           3
#                                            ..
# [phosphine, thiol]                          3
# [phosphine, trimethylphosphine]             3
# [thiol, thiol]                              3
# [thiol, trimethylphosphine]                 3
# [trimethylphosphine, trimethylphosphine]    3
# Name: count, Length: 103, dtype: int64
# Total unique values: 103
#
# Column: total_charge
# ============================================================
# total_charge
# 0      1
# 2    309
# Name: count, dtype: int64
# Total unique values: 2
#
# Column: multiplicity
# ============================================================
# multiplicity
# 5    169
# 6    141
# Name: count, dtype: int64
# Total unique values: 2
