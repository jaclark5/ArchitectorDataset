# %% [markdown]
# ## Define Chemical Space

# %%
import os
import sys
import json
from itertools import combinations_with_replacement
from collections import defaultdict
from math import comb
import glob

import numpy as np
import pandas as pd
from rdkit import Chem
import rdkit
rdkit.__version__

from architector import build_complex, io_core
from nglview import show_rdkit

#core_geometries = io_core.Geometries().cn_geo_dict
core_geometries = {
    1: ['single'], 
    2: ['bent_109', 'bent_120', 'linear'], 
    3: ['t_shaped', 'trigonal_planar', 'trigonal_pyramidal'], 
    4: ['seesaw', 'square_planar', 'tetrahedral'], 
    5: ['pentagonal_planar', 'square_pyramidal', 'trigonal_bipyramidal'], 
    6: ['hexagonal_planar', 'octahedral', 'pentagonal_pyramidal', 'trigonal_prismatic'], 
    7: ['capped_octahedral', 'capped_trigonal_prismatic', 'hexagonal_pyramidal', 'pentagonal_bipyramidal'], 
    8: ['axial_bicapped_trigonal_prismatic', 'bicapped_trigonal_prismatic', 'dodecahedral', 'hexagonal_bipyramidal', 'square_antiprismatic', 'square_prismatic'], 
    9: ['capped_square_antiprismatic', 'tri_tri_mer_capped', 'tricapped_trigonal_prismatic'], 
    10: ['axial_bicapped_hexagonal_planar'], 
    12: ['penta_bi_capped_pyramidal']
}

def view3D(mol):
    """Display an RDKit molecule in 3D using nglview"""
    return show_rdkit(mol)

# %%
#import mendeleev
#sorted([x.oxidation_state for x in mendeleev.element("Fe")._oxidation_states])
metal_ox = {
#    "Fe": [2],
    "Fe": [0, 1, 2, 3, 4, 5, 6, 7],
#    "Pd": [1, 2, 3, 4, 5],
#    "Zn": [0, 1, 2],
#    "Cu": [0, 1, 2, 3, 4],
#    "Li": [1],
#    "Mg": [0, 1, 2],
}

# %%
# Removed:
#     "hydride": {"smiles":"H", "coordList":[0], "ligType":"mono", "bondType": "X", "charge": 0},
ligands = {}
with open("../ligand_dictionaries/ligands.json", "r") as f:
    ligands.update(json.load(f))

for lig_name, tmp in ligands.items():
    print(lig_name, tmp["smiles"])
    
ligands_list = sorted(ligands.items())
# Out:
# choride Cl
# methyl [C-1]([H])([H])[H]
# methanediide [C-2]([H])[H]
# ammonia [N][H][H][H]
# amine [N-1]([H])[H]
# imido [N-2][H]
# water [O][H][H]
# hydroxyl [O-1][H]
# oxo [O-2]
# phosphine P([H])([H])[H]
# phosphido [P-1]([H])[H]
# hydrogen sulfide [S]([H])[H]
# thiol [S-1][H]
# sulfido [S-2]

# %% [markdown]
# ## Check Fringe Chemical Space

# %%
## Fluoride
#ligands = [x[0] for x in ligands_list]
#
#ox_state = 3
#inpDict = {
#    "core": {"metal": "Fe", 'coreCN': 6, "coreType": ['trigonal_prismatic']},
#    "ligands": [x[1] for lig in ligands for x in ligands_list if x[0] == lig],
#    'parameters':{
#        "metal_ox": ox_state,
#        'assemble_method':'GFN-FF', # Switch to GFN-FF for faster assembly, 
#        'n_symmetries': 100, # build 5 structures with different ligand arrangements, duplicates will be filtered
#        'n_conformers': 1,
#        'debug': True,
#        'save_init_geos': True,  # Save pre-optimization structure
##        'seed': 42,  # Also set this (though OpenBabel still has randomness)
#    },
#    
#}
#
#out_dict = build_complex(inpDict)
#for x in out_dict.keys():
#    print(x)

# %%
#out_dict

# %%
#for label, out in out_dict.items():
#    n_el = [out['xtb_n_unpaired_electrons'], out['calc_n_unpaired_electrons']]
#    if len(set(n_el)) > 1:
#        raise ValueError(f"N_unpaired_el should agree between keys: 'xtb_n_unpaired_electrons', 'calc_n_unpaired_electrons', 'metal_spin', resulting {n_el}")
#    chg = [out['total_charge'], out['xtb_total_charge']]
#    if len(set(chg)) > 1:
#        raise ValueError(f"Charge should agree between keys: 'total_charge', 'xtb_total_charge', resulting {chg}")
#    if ox_state != out["metal_ox"]:
#        raise ValueError("Metal oxidation state is not equal to assigned.")

# %%
#list(out_dict.values())[0]

# %%
#mol = Chem.MolFromMol2Block(out['mol2string'], removeHs=False)
#show_rdkit(mol)

# %%
#sys.exit()

# %% [markdown]
# ## Generate Dataset

# %% [markdown]
# ### Check Geometry of TMOS

# %%
import pickle

# Checkpoint file to save progress
CHECKPOINT_FILE = "dataset_checkpoint.pkl"
PROGRESS_LOG = "dataset_progress.txt"

def save_checkpoint(data_dict, progress_state):
    """Save current dataframe and progress state"""
    with open(CHECKPOINT_FILE, 'wb') as f:
        pickle.dump({'data': data_dict, 'state': progress_state}, f)
    print(f"✓ Checkpoint saved: {len(data_dict['metals'])} complexes", flush=True)

def load_checkpoint():
    """Load previous checkpoint if it exists"""
    try:
        with open(CHECKPOINT_FILE, 'rb') as f:
            checkpoint = pickle.load(f)
            print(f"✓ Loaded checkpoint: {len(checkpoint['data']['metals'])} complexes")
            return checkpoint['data'], checkpoint['state']
    except FileNotFoundError:
        print("No checkpoint found, starting fresh")
        return None, None

def make_state_key(metal, ox_state, cn, ligand_labels, coreType):
    """Create unique key for current state"""
    return f"{metal}_{ox_state}_{cn}_{coreType}_{'_'.join(sorted(ligand_labels))}"

# %% [markdown]
# ### Strategy for Handling Kernel Crashes
#
# Since the kernel can crash during `build_complex` (likely due to underlying C/Fortran code in xtb), we need to:
# 1. Save progress incrementally to disk
# 2. Restart from the last saved checkpoint if the kernel crashes

# %%
coordination_numbers = list(range(2, 13)) # to 13
exclude_functional_inds = True
errors = defaultdict(list)

# Load checkpoint if exists
checkpoint_data, last_state = load_checkpoint()
if checkpoint_data:
    df_metals = checkpoint_data['metals']
    df_cn = checkpoint_data['cn']
    df_ligands = checkpoint_data['ligands']
    df_ox = checkpoint_data['ox']
    df_chg = checkpoint_data['chg']
    df_multiplicity = checkpoint_data['multiplicity']
    df_mol2 = checkpoint_data['mol2']
    df_geo = checkpoint_data['geo']
    df_energy = checkpoint_data['energy']
    errors = checkpoint_data.get('errors', defaultdict(list))
    print(f"Resuming from checkpoint with {len(df_metals)} existing complexes")
else:
    # Start fresh
    df_metals, df_cn, df_ligands, df_ox, df_chg, df_multiplicity, df_mol2, df_geo, df_energy = [], [], [], [], [], [], [], [], []
    last_state = None

# Track processed states to avoid duplicates
if checkpoint_data:
    processed_states = set(make_state_key(
        checkpoint_data['metals'][i], 
        checkpoint_data['ox'][i], 
        checkpoint_data['cn'][i], 
        checkpoint_data['ligands'][i], 
        checkpoint_data['geo'][i],
    ) for i in range(len(checkpoint_data)))
else:
    processed_states = set()

checkpoint_counter = 0
CHECKPOINT_EVERY = 5  # Save every N successful complexes

n_metal_ox = sum(len(x) for x in metal_ox.values())
n_coord_geo = sum(comb(len(ligands_list) + cn - 1, cn) for cn in coordination_numbers)
print(f"Analyzing {n_metal_ox * n_coord_geo - len(df_metals)} structures")

for metal, ox_states in metal_ox.items():
    for ox_state in ox_states:
        for cn in coordination_numbers:
            for combo in combinations_with_replacement(ligands_list, cn):
                for coreType in core_geometries[cn]:
                    ligand_labels = [x[0] for x in combo]
                    state_key = make_state_key(metal, ox_state, cn, ligand_labels, coreType)
                    
                    # Skip if already processed
                    if state_key in processed_states:
                        continue
                    
                    ligand_dicts = [x[1] for x in combo]
                    if exclude_functional_inds:
                        ligand_dicts = [{k: v for k, v in lig.items() if k != 'functional_inds'} for lig in ligand_dicts]

                    # Log to file in case kernel dies
                    with open(PROGRESS_LOG, 'a') as f:
                        f.write(f"STARTING: {state_key}\n")
                    
                    print(f"\nProcessing: {metal=}, {ox_state=}, {cn=}, {coreType=}, ligands={ligand_labels}", flush=True)
                    
                    inpDict = {
                        "core": {"metal": metal, 'coreCN': cn, "coreType": [coreType]},
                        "ligands": ligand_dicts,
                        'parameters':{
                            "metal_ox": ox_state,
                            'assemble_method':'GFN-FF', # Switch to GFN-FF for faster assembly, 
                            'n_symmetries': 100, # build 5 structures with different ligand arrangements, duplicates will be filtered
                            'n_conformers': 1,
                            'return_only_1':True # Return just one geometry with lowest energy
                        },
                    }

                    try:
                        print("  Calling build_complex...", flush=True)
                        out = next(iter(build_complex(inpDict).values()))
                        print("  build_complex completed", flush=True)
                        
                        n_el = [out['xtb_n_unpaired_electrons'], out['calc_n_unpaired_electrons']]
                        if len(set(n_el)) > 1:
                            raise ValueError(f"N_unpaired_el should agree between keys: 'xtb_n_unpaired_electrons', 'calc_n_unpaired_electrons', 'metal_spin', resulting {n_el}")
                        chg = [out['total_charge'], out['xtb_total_charge']]
                        if len(set(chg)) > 1:
                            raise ValueError(f"Charge should agree between keys: 'total_charge', 'xtb_total_charge', resulting {chg}")
                        if ox_state != out["metal_ox"]:
                            raise ValueError("Metal oxidation state is not equal to assigned.")
                    except Exception as e:
                        error_msg = f"{type(e).__name__}: {str(e)[:100]}"
                        print(f"  ERROR: {error_msg}", flush=True)
                        errors[str(e)[:30]].append([metal, ox_state, cn, ligand_labels, coreType, e])
                        with open(PROGRESS_LOG, 'a') as f:
                            f.write(f"ERROR: {state_key} - {error_msg}\n")
                    else:
                        print("  SUCCESS", flush=True)
                        df_metals.append(metal)
                        df_ox.append(ox_state)
                        df_cn.append(cn)
                        df_geo.append(coreType)
                        df_ligands.append(ligand_labels)
                        df_chg.append(out['total_charge'])
                        df_multiplicity.append(out['xtb_n_unpaired_electrons'] + 1)
                        df_mol2.append(out['mol2string'])
                        df_energy.append(out['energy'])
                        
                        checkpoint_counter += 1
                        
                        # Save checkpoint periodically
                        if checkpoint_counter >= CHECKPOINT_EVERY:
                            data_dict = {
                                'metals': df_metals, 'cn': df_cn, 'ligands': df_ligands,
                                'ox': df_ox, 'chg': df_chg, 'multiplicity': df_multiplicity,
                                'mol2': df_mol2, 'geo': df_geo, 'energy': df_energy,
                                'errors': errors
                            }
                            save_checkpoint(data_dict, state_key)
                            checkpoint_counter = 0
                        
                        with open(PROGRESS_LOG, 'a') as f:
                            f.write(f"SUCCESS: {state_key}\n")
                    
                    processed_states.add(state_key)


# Final checkpoint
data_dict = {
    'metals': df_metals, 'cn': df_cn, 'ligands': df_ligands,
    'ox': df_ox, 'chg': df_chg, 'multiplicity': df_multiplicity,
    'mol2': df_mol2, 'geo': df_geo, 'energy': df_energy,
    'errors': errors
}
save_checkpoint(data_dict, "COMPLETED")

df = pd.DataFrame({
    "metal": df_metals,
    "oxidation_state": df_ox,
    "coordination_number": df_cn,
    "geometry": df_geo,
    "ligand_names": df_ligands,
    "total_charge": df_chg,
    "multiplicity": df_multiplicity,
    "mol2string": df_mol2,
    "xtb_energy": df_energy,
}) # Create a dataframe

print(f"\nGenerated {len(df)} complexes with {len(errors)} error types.")
# Out:
# No checkpoint found, starting fresh
# Analyzing 14520 structures
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['amine', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 5 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['amine', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 10 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 15 complexes
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['methyl', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_109', ligands=['phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='bent_120', ligands=['phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=2, coreType='linear', ligands=['phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'amine', 'amine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 20 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'amine', 'amine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'amine', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'amine', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 25 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 30 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 35 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 40 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 45 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 50 complexes
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='t_shaped', ligands=['phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_planar', ligands=['phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=3, coreType='trigonal_pyramidal', ligands=['phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 55 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 60 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 65 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 70 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 75 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 80 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 85 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 90 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 95 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['amine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['amine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['amine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 100 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 105 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 110 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 115 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['fluoride', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 120 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['fluoride', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['fluoride', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['methyl', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['methyl', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['methyl', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 125 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['methyl', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['methyl', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['methyl', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['methyl', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['methyl', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 130 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['methyl', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['methyl', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['methyl', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['methyl', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='seesaw', ligands=['phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 135 complexes
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='square_planar', ligands=['phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=4, coreType='tetrahedral', ligands=['phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 140 complexes
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'fluoride', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 145 complexes
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 150 complexes
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 155 complexes
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'fluoride', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'fluoride', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 160 complexes
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'fluoride', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'methyl', 'methyl', 'methyl']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 165 complexes
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'methyl', 'methyl', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 170 complexes
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'methyl', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'amine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'amine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'amine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='trigonal_bipyramidal', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='pentagonal_planar', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=5, coreType='square_pyramidal', ligands=['amine', 'fluoride', 'fluoride', 'fluoride', 'phosphine']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# ...
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='hexagonal_planar', ligands=['methyl', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='octahedral', ligands=['methyl', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='pentagonal_pyramidal', ligands=['methyl', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 515 complexes
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='trigonal_prismatic', ligands=['methyl', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='hexagonal_planar', ligands=['phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='octahedral', ligands=['phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='pentagonal_pyramidal', ligands=['phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=6, coreType='trigonal_prismatic', ligands=['phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 520 complexes
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='am_c3_7H2O_c0', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_octahedral', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_trigonal_prismatic', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='hexagonal_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='pentagonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'amine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 525 complexes
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='am_c3_7H2O_c0', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_octahedral', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_trigonal_prismatic', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='hexagonal_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='pentagonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'fluoride']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='am_c3_7H2O_c0', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_octahedral', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_trigonal_prismatic', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='hexagonal_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='pentagonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'methyl']
#   Calling build_complex...
#   ERROR: StopIteration:
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='am_c3_7H2O_c0', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_octahedral', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
# ✓ Checkpoint saved: 530 complexes
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_trigonal_prismatic', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='hexagonal_pyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='pentagonal_bipyramidal', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'amine', 'phosphine']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='am_c3_7H2O_c0', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
#   build_complex completed
#   SUCCESS
#
# Processing: metal='Fe', ox_state=0, cn=7, coreType='capped_octahedral', ligands=['amine', 'amine', 'amine', 'amine', 'amine', 'fluoride', 'fluoride']
#   Calling build_complex...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 80
#      78 try:
#      79     print("  Calling build_complex...", flush=True)
# ---> 80     out = next(iter(build_complex(inpDict).values()))
#      81     print("  build_complex completed", flush=True)
#      83     n_el = [out['xtb_n_unpaired_electrons'], out['calc_n_unpaired_electrons']]
#
# File ~/bin/Architector/architector/complex_construction.py:681, in build_complex(inputDict)
#     664 def build_complex(inputDict):
#     665     """build_complex build a complex!
#     666     main function for architector!!!!
#     667     Attempts a default radii, larger radii, and smaller radii build_complex_driver
#    (...)    679         ordered structures and outputs as valid
#     680     """
# --> 681     ordered_conf_dict = build_complex_driver(inputDict)
#     682     # Try larger radii generation for multidentate complexes if no complexes generated in an attempt to get at high-spin
#     683     # > Covalent radii typically understimated for higher spin conformations
#     684     in_metal = inputDict['parameters']['original_metal']
#
# File ~/bin/Architector/architector/complex_construction.py:570, in build_complex_driver(inputDict1, in_metal)
#     555 def build_complex_driver(inputDict1,in_metal=False):
#     556     """build_complex_driver overall driver building of the complex
#     557
#     558     Parameters
#    (...)    568         Conformer dictionary with stored values if generation successful.
#     569     """
# --> 570     conf_dict,inputDict,core_preprocess_time,symmetry_preprocess_time,int_time1 = complex_driver(inputDict1=inputDict1,in_metal=in_metal)
#     571     if len(conf_dict) == 0:
#     572         if inputDict['parameters']['debug']:
#
# File ~/bin/Architector/architector/complex_construction.py:502, in complex_driver(inputDict1, in_metal)
#     500             break
#     501 else: # Use the first conformer ligand structures to map to other symmetries
# --> 502     tcomplexClass, _ = gen_aligned_complex(
#     503             newLigInputDicts,
#     504             ligandDict,
#     505             inputDict,
#     506             ligLists,
#     507             coreCoordList,
#     508             coreType)
#     509     if (tcomplexClass is not None):
#     510         complexClass = tcomplexClass
#
# File ~/bin/Architector/architector/complex_construction.py:402, in gen_aligned_complex(newLigInputDicts, ligandDict, inputDict, ligLists, coreCoordList, coreType)
#     400 coreCoordList = coreCoordList
#     401 complexClass = Complex(coreSmiles, coreCoordList, ligandList, inputDict['parameters'])
# --> 402 complexClass.final_eval(single_point=True) # Key here - have singlepoints during assembly be defined by assembly params.
#     403 if inputDict['parameters']['debug']:
#     404     print('Complex class generated: ', complexClass.calculator.successful)
#
# File ~/bin/Architector/architector/complex_construction.py:256, in Complex.final_eval(self, single_point)
#     254 if self.parameters['debug']:
#     255     print("Final Evaluation - Opt Molecule/Single point, Single Point? {}".format(single_point))
# --> 256 self.calculator = CalcExecutor(self.complexMol,
#     257                                parameters=self.parameters,
#     258                                final_sanity_check=self.parameters['full_sanity_checks'],
#     259                                relax=(not single_point),
#     260                                assembly=False)
#     261 if (self.parameters['debug']) and (self.calculator):
#     262     print('Finished method: {} {}.'.format(self.calculator.method,
#     263                                         self.calculator.relax))
#
# File ~/bin/Architector/architector/io_calc.py:193, in CalcExecutor.__init__(self, structure, parameters, init_sanity_check, final_sanity_check, relax, assembly, method, xtb_solvent, xtb_accuracy, xtb_electronic_temperature, xtb_max_iterations, fmax, maxsteps, ff_preopt_run, detect_spin_charge, fix_m_neighbors, default_params, ase_opt_method, species_run, calculator)
#     191 self.calc_time = time.time()
#     192 self.done = False
# --> 193 self.calculate()
#
# File ~/bin/Architector/architector/io_calc.py:255, in CalcExecutor.calculate(self)
#     253     else:
#     254         dyn = self.opt_method(self.mol.ase_atoms)
# --> 255 dyn.run(fmax=self.fmax,steps=self.maxsteps)
#     256 if self.parameters['save_trajectories']:
#     257     self.read_traj()
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/optimize/optimize.py:417, in Optimizer.run(self, fmax, steps)
#     402 """Run optimizer.
#     403
#     404 Parameters
#    (...)    414     True if the forces on atoms are converged.
#     415 """
#     416 self.fmax = fmax
# --> 417 return Dynamics.run(self, steps=steps)
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/optimize/optimize.py:286, in Dynamics.run(self, steps)
#     268 def run(self, steps=DEFAULT_MAX_STEPS):
#     269     """Run dynamics algorithm.
#     270
#     271     This method will return when the forces on all individual
#    (...)    283         True if the forces on atoms are converged.
#     284     """
# --> 286     for converged in Dynamics.irun(self, steps=steps):
#     287         pass
#     288     return converged
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/optimize/optimize.py:257, in Dynamics.irun(self, steps)
#     254 # run the algorithm until converged or max_steps reached
#     255 while not is_converged and self.nsteps < self.max_steps:
#     256     # compute the next step
# --> 257     self.step()
#     258     self.nsteps += 1
#     260     # log the step
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/optimize/lbfgs.py:158, in LBFGS.step(self, forces)
#     156 if self.use_line_search is True:
#     157     e = self.func(pos)
# --> 158     self.line_search(pos, g, e)
#     159     dr = (self.alpha_k * self.p).reshape(len(self.optimizable), -1)
#     160 else:
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/optimize/lbfgs.py:247, in LBFGS.line_search(self, r, g, e)
#     244 r = r.ravel()
#     245 ls = LineSearch()
#     246 self.alpha_k, e, self.e0, self.no_update = \
# --> 247     ls._line_search(self.func, self.fprime, r, self.p, g, e, self.e0,
#     248                     maxstep=self.maxstep, c1=.23,
#     249                     c2=.46, stpmax=50.)
#     250 if self.alpha_k is None:
#     251     raise RuntimeError('LineSearch failed!')
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/utils/linesearch.py:61, in LineSearch._line_search(self, func, myfprime, xk, pk, gfk, old_fval, old_old_fval, maxstep, c1, c2, xtrapl, xtrapu, stpmax, stpmin, args)
#      59 if self.task[:2] == 'FG':
#      60     alpha1 = stp
# ---> 61     fval = func(xk + stp * pk, *args)
#      62     self.fc += 1
#      63     gval = fprime(xk + stp * pk, *newargs)
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/optimize/lbfgs.py:229, in LBFGS.func(self, x)
#     227 self.optimizable.set_positions(x.reshape(-1, 3))
#     228 self.function_calls += 1
# --> 229 return self.optimizable.get_potential_energy()
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/optimize/optimize.py:59, in OptimizableAtoms.get_potential_energy(self)
#      57 def get_potential_energy(self):
#      58     force_consistent = self._use_force_consistent_energy
# ---> 59     return self.atoms.get_potential_energy(
#      60         force_consistent=force_consistent)
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/atoms.py:772, in Atoms.get_potential_energy(self, force_consistent, apply_constraint)
#     769     energy = self._calc.get_potential_energy(
#     770         self, force_consistent=force_consistent)
#     771 else:
# --> 772     energy = self._calc.get_potential_energy(self)
#     773 if apply_constraint:
#     774     for constraint in self.constraints:
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/calculators/abc.py:26, in GetPropertiesMixin.get_potential_energy(self, atoms, force_consistent)
#      24 else:
#      25     name = 'energy'
# ---> 26 return self.get_property(name, atoms)
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/ase/calculators/calculator.py:515, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     512     if self.use_cache:
#     513         self.atoms = atoms.copy()
# --> 515     self.calculate(atoms, [name], system_changes)
#     517 if name not in self.results:
#     518     # For some reason the calculator was not able to do what we want,
#     519     # and that is OK.
#     520     raise PropertyNotImplementedError(
#     521         '{} not present in this ' 'calculation'.format(name)
#     522     )
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/xtb/ase/calculator.py:231, in XTB.calculate(self, atoms, properties, system_changes)
#     228     self._xtb = self._create_api_calculator()
#     230 try:
# --> 231     self._res = self._xtb.singlepoint(self._res)
#     232 except XTBException:
#     233     raise ase_calc.CalculationFailed("xtb could not evaluate input")
#
# File ~/mamba/envs/architector/lib/python3.12/site-packages/xtb/interface.py:821, in Calculator.singlepoint(self, res, copy)
#     818 else:
#     819     _res = Results(self)
# --> 821 _lib.xtb_singlepoint(
#     822     self._env, self._mol, self._calc, _res._res,
#     823 )
#     825 if self.check() != 0:
#     826     raise XTBException(self.get_error("Single point calculation failed"))
#
# KeyboardInterrupt:

# %%
len(df)
# Out:
# 310

# %%
keys = list(errors.keys())
keys
# Out:
# ['']

# %%
df.head()
# Out:
#   metal  oxidation_state  coordination_number  geometry      ligand_names  \
# 0    Fe                2                    2  bent_109    [amine, amine]
# 1    Fe                2                    2  bent_120    [amine, amine]
# 2    Fe                2                    2    linear    [amine, amine]
# 3    Fe                2                    2  bent_109  [amine, bromide]
# 4    Fe                2                    2  bent_120  [amine, bromide]
#
#    total_charge  multiplicity  \
# 0             2             5
# 1             2             5
# 2             2             5
# 3             2             5
# 4             2             5
#
#                                           mol2string  xtb_energy
# 0  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -298.173926
# 1  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -298.174912
# 2  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -298.173683
# 3  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -301.972133
# 4  @<TRIPOS>MOLECULE\nbent_109_0_nunpairedes_4_ch... -301.971854

# %%
# Analyze each column independently for unique values and their counts
columns_to_analyze = ['metal', 'oxidation_state', 'coordination_number', 'geometry', 'ligand_names', 'total_charge', 'multiplicity']

for col in columns_to_analyze:
    print(f"\nColumn: {col}")
    print(f"{'='*60}")
    value_counts = df[col].value_counts().sort_index()
    print(value_counts)
    print(f"Total unique values: {len(value_counts)}")
# Out:
# Column: metal
# ============================================================
# metal
# Fe    310
# Name: count, dtype: int64
# Total unique values: 1
#
# Column: oxidation_state
# ============================================================
# oxidation_state
# 0      1
# 2    309
# Name: count, dtype: int64
# Total unique values: 2
#
# Column: coordination_number
# ============================================================
# coordination_number
# 2    310
# Name: count, dtype: int64
# Total unique values: 1
#
# Column: geometry
# ============================================================
# geometry
# bent_109    104
# bent_120    103
# linear      103
# Name: count, dtype: int64
# Total unique values: 3
#
# Column: ligand_names
# ============================================================
# ligand_names
# [amine, amine]                              4
# [amine, bromide]                            3
# [amine, choride]                            3
# [amine, dimethylamine]                      3
# [amine, fluoride]                           3
#                                            ..
# [phosphine, thiol]                          3
# [phosphine, trimethylphosphine]             3
# [thiol, thiol]                              3
# [thiol, trimethylphosphine]                 3
# [trimethylphosphine, trimethylphosphine]    3
# Name: count, Length: 103, dtype: int64
# Total unique values: 103
#
# Column: total_charge
# ============================================================
# total_charge
# 0      1
# 2    309
# Name: count, dtype: int64
# Total unique values: 2
#
# Column: multiplicity
# ============================================================
# multiplicity
# 5    169
# 6    141
# Name: count, dtype: int64
# Total unique values: 2
